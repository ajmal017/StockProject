# %% [markdown]
# # Data Wrangling - MarketWatch Analyst Rating Scraper

# %% [markdown]
# Note: this workbook is 1 of 4 scraping and extracting processes that ultimately aggregate into the Technical Indicators workbook in the Data Wrangling phase of capstone 3
#
#
# * Fundamental Scraper - scrapes 5 years worth of fundamental company financial data from MarketWatch using Beautiful Soup from the S&P 500 list
# * Fundamental Calcs  - imports scraped data from the scraper tool, converts text data to numeric - i.e. 5.00M to 5000000 - using regular expressions, and calculates additonal financial metrics
# * <span style="color:red"> **Analyst Scraper (this workbook)** </span> - scrapes analyst buy, sell, hold ratings for all S&P 500 stocks and downloads to .csv file
# * Mass Yahoo Download and Technical Analysis - downloads 5 years of daily stock pricing data from the S&P 500, Runs complex Directional Index, ADX, Bollinger Band, and other financial charting data. Merges data from fundamental and analyst scrapers

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from datetime import date
import re

import numpy as np

# %%
import os
importfile = 'SandP.csv'
importpath = r'C:\Users\nmur1\Google Drive\Springboard\Capstone2\Stock Import Lists'
exportpath = r'C:\Users\nmur1\Google Drive\Springboard\Capstone2\CleanData'
exportfile = 'Analysts.csv'
os.chdir(importpath)

# %%
Company = pd.read_csv(importfile, encoding= 'unicode_escape')
Company.head()
# Out:
#   Symbol                 Name       Sector
# 0    MMM           3M Company  Industrials
# 1    AOS      A.O. Smith Corp  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV          AbbVie Inc.  Health Care
# 4   ABMD          ABIOMED Inc  Health Care

# %%
dfAnalysts = []

CompList = Company.Symbol
i = 0

for ticker in CompList:

    #open website
    try:
        urlfinancials = 'https://www.marketwatch.com/investing/stock/'+ ticker + '/analystestimates'
        res = requests.get(urlfinancials)

        #parse reccomendation
        text_soup_recs = BeautifulSoup(requests.get(urlfinancials).text,"lxml") #read in
        recs = text_soup_recs.find('td', {'class': 'recommendation'})
        recs = [i.strip() for i in recs]


        #parse target price
        price = text_soup_recs.find("td", {'class': 'first column2'}).find_next_sibling("td").text
        try:
            price = int(str(price).replace(',',''))
        except:
            price = price
        #get all ratings

        ratings = []
        rec_list = ['Buy','Overweight','Hold','Underweight', 'Sell']

        for name in text_soup_recs.findAll("td", {'class': 'current'}):
            ratings.append(name.text)

        ratings = np.array(ratings[:-1]).astype('int64')
        dictrec = dict(zip(rec_list,ratings))

        dfRatings = pd.DataFrame(dictrec, index = [i])

        dfRatings['Symbol'] = str(ticker).upper()
        dfRatings['Analyst_Price'] = price
        dfRatings['Analyst_Rec'] = recs
        dfAnalysts.append(dfRatings)
        i = i + 1
        print('downloading ', i, ' of ', len(CompList))
    
    except:
        print(ticker, ' not found')
# Out:
# downloading  1  of  505
# downloading  2  of  505
# downloading  3  of  505
# downloading  4  of  505
# downloading  5  of  505
# downloading  6  of  505
# downloading  7  of  505
# downloading  8  of  505
# downloading  9  of  505
# downloading  10  of  505
# downloading  11  of  505
# downloading  12  of  505
# downloading  13  of  505
# downloading  14  of  505
# downloading  15  of  505
# downloading  16  of  505
# downloading  17  of  505
# downloading  18  of  505
# downloading  19  of  505
# downloading  20  of  505
# downloading  21  of  505
# downloading  22  of  505
# downloading  23  of  505
# downloading  24  of  505
# downloading  25  of  505
# downloading  26  of  505
# downloading  27  of  505
# downloading  28  of  505
# downloading  29  of  505
# downloading  30  of  505
# downloading  31  of  505
# downloading  32  of  505
# downloading  33  of  505
# downloading  34  of  505
# downloading  35  of  505
# downloading  36  of  505
# downloading  37  of  505
# downloading  38  of  505
# downloading  39  of  505
# downloading  40  of  505
# downloading  41  of  505
# downloading  42  of  505
# downloading  43  of  505
# downloading  44  of  505
# downloading  45  of  505
# downloading  46  of  505
# downloading  47  of  505
# downloading  48  of  505
# downloading  49  of  505
# downloading  50  of  505
# downloading  51  of  505
# downloading  52  of  505
# downloading  53  of  505
# downloading  54  of  505
# downloading  55  of  505
# downloading  56  of  505
# downloading  57  of  505
# downloading  58  of  505
# downloading  59  of  505
# downloading  60  of  505
# downloading  61  of  505
# downloading  62  of  505
# downloading  63  of  505
# downloading  64  of  505
# downloading  65  of  505
# downloading  66  of  505
# downloading  67  of  505
# downloading  68  of  505
# downloading  69  of  505
# downloading  70  of  505
# downloading  71  of  505
# downloading  72  of  505
# downloading  73  of  505
# downloading  74  of  505
# downloading  75  of  505
# downloading  76  of  505
# downloading  77  of  505
# downloading  78  of  505
# downloading  79  of  505
# downloading  80  of  505
# downloading  81  of  505
# downloading  82  of  505
# downloading  83  of  505
# downloading  84  of  505
# downloading  85  of  505
# downloading  86  of  505
# downloading  87  of  505
# downloading  88  of  505
# downloading  89  of  505
# downloading  90  of  505
# downloading  91  of  505
# downloading  92  of  505
# downloading  93  of  505
# downloading  94  of  505
# downloading  95  of  505
# downloading  96  of  505
# downloading  97  of  505
# downloading  98  of  505
# downloading  99  of  505
# downloading  100  of  505
# downloading  101  of  505
# downloading  102  of  505
# downloading  103  of  505
# downloading  104  of  505
# downloading  105  of  505
# downloading  106  of  505
# downloading  107  of  505
# downloading  108  of  505
# downloading  109  of  505
# downloading  110  of  505
# downloading  111  of  505
# downloading  112  of  505
# downloading  113  of  505
# downloading  114  of  505
# downloading  115  of  505
# downloading  116  of  505
# downloading  117  of  505
# downloading  118  of  505
# downloading  119  of  505
# downloading  120  of  505
# downloading  121  of  505
# downloading  122  of  505
# downloading  123  of  505
# downloading  124  of  505
# downloading  125  of  505
# downloading  126  of  505
# downloading  127  of  505
# downloading  128  of  505
# downloading  129  of  505
# downloading  130  of  505
# downloading  131  of  505
# downloading  132  of  505
# downloading  133  of  505
# downloading  134  of  505
# downloading  135  of  505
# downloading  136  of  505
# downloading  137  of  505
# downloading  138  of  505
# downloading  139  of  505
# downloading  140  of  505
# downloading  141  of  505
# downloading  142  of  505
# downloading  143  of  505
# downloading  144  of  505
# downloading  145  of  505
# downloading  146  of  505
# downloading  147  of  505
# downloading  148  of  505
# downloading  149  of  505
# downloading  150  of  505
# downloading  151  of  505
# downloading  152  of  505
# downloading  153  of  505
# downloading  154  of  505
# downloading  155  of  505
# downloading  156  of  505
# downloading  157  of  505
# downloading  158  of  505
# downloading  159  of  505
# downloading  160  of  505
# downloading  161  of  505
# downloading  162  of  505
# downloading  163  of  505
# downloading  164  of  505
# downloading  165  of  505
# downloading  166  of  505
# downloading  167  of  505
# downloading  168  of  505
# downloading  169  of  505
# downloading  170  of  505
# downloading  171  of  505
# downloading  172  of  505
# downloading  173  of  505
# downloading  174  of  505
# downloading  175  of  505
# downloading  176  of  505
# downloading  177  of  505
# downloading  178  of  505
# downloading  179  of  505
# downloading  180  of  505
# downloading  181  of  505
# downloading  182  of  505
# downloading  183  of  505
# downloading  184  of  505
# downloading  185  of  505
# downloading  186  of  505
# downloading  187  of  505
# downloading  188  of  505
# downloading  189  of  505
# downloading  190  of  505
# downloading  191  of  505
# downloading  192  of  505
# downloading  193  of  505
# downloading  194  of  505
# downloading  195  of  505
# downloading  196  of  505
# downloading  197  of  505
# downloading  198  of  505
# downloading  199  of  505
# downloading  200  of  505
# downloading  201  of  505
# downloading  202  of  505
# downloading  203  of  505
# FCX  not found
# downloading  204  of  505
# downloading  205  of  505
# downloading  206  of  505
# downloading  207  of  505
# downloading  208  of  505
# downloading  209  of  505
# downloading  210  of  505
# downloading  211  of  505
# downloading  212  of  505
# downloading  213  of  505
# downloading  214  of  505
# downloading  215  of  505
# downloading  216  of  505
# downloading  217  of  505
# downloading  218  of  505
# downloading  219  of  505
# downloading  220  of  505
# downloading  221  of  505
# downloading  222  of  505
# downloading  223  of  505
# downloading  224  of  505
# downloading  225  of  505
# downloading  226  of  505
# downloading  227  of  505
# downloading  228  of  505
# downloading  229  of  505
# downloading  230  of  505
# downloading  231  of  505
# downloading  232  of  505
# downloading  233  of  505
# downloading  234  of  505
# downloading  235  of  505
# downloading  236  of  505
# downloading  237  of  505
# downloading  238  of  505
# downloading  239  of  505
# downloading  240  of  505
# downloading  241  of  505
# downloading  242  of  505
# downloading  243  of  505
# downloading  244  of  505
# downloading  245  of  505
# downloading  246  of  505
# downloading  247  of  505
# downloading  248  of  505
# downloading  249  of  505
# downloading  250  of  505
# downloading  251  of  505
# downloading  252  of  505
# downloading  253  of  505
# downloading  254  of  505
# downloading  255  of  505
# downloading  256  of  505
# downloading  257  of  505
# downloading  258  of  505
# downloading  259  of  505
# downloading  260  of  505
# downloading  261  of  505
# downloading  262  of  505
# downloading  263  of  505
# downloading  264  of  505
# downloading  265  of  505
# downloading  266  of  505
# downloading  267  of  505
# downloading  268  of  505
# downloading  269  of  505
# downloading  270  of  505
# downloading  271  of  505
# downloading  272  of  505
# downloading  273  of  505
# downloading  274  of  505
# downloading  275  of  505
# downloading  276  of  505
# downloading  277  of  505
# downloading  278  of  505
# downloading  279  of  505
# downloading  280  of  505
# downloading  281  of  505
# downloading  282  of  505
# downloading  283  of  505
# downloading  284  of  505
# downloading  285  of  505
# downloading  286  of  505
# downloading  287  of  505
# downloading  288  of  505
# downloading  289  of  505
# downloading  290  of  505
# downloading  291  of  505
# downloading  292  of  505
# downloading  293  of  505
# downloading  294  of  505
# downloading  295  of  505
# downloading  296  of  505
# downloading  297  of  505
# downloading  298  of  505
# downloading  299  of  505
# downloading  300  of  505
# downloading  301  of  505
# downloading  302  of  505
# downloading  303  of  505
# downloading  304  of  505
# downloading  305  of  505
# downloading  306  of  505
# downloading  307  of  505
# downloading  308  of  505
# downloading  309  of  505
# downloading  310  of  505
# downloading  311  of  505
# downloading  312  of  505
# downloading  313  of  505
# downloading  314  of  505
# downloading  315  of  505
# downloading  316  of  505
# downloading  317  of  505
# downloading  318  of  505
# downloading  319  of  505
# downloading  320  of  505
# downloading  321  of  505
# downloading  322  of  505
# downloading  323  of  505
# downloading  324  of  505
# downloading  325  of  505
# downloading  326  of  505
# downloading  327  of  505
# downloading  328  of  505
# downloading  329  of  505
# downloading  330  of  505
# downloading  331  of  505
# downloading  332  of  505
# downloading  333  of  505
# downloading  334  of  505
# downloading  335  of  505
# downloading  336  of  505
# downloading  337  of  505
# downloading  338  of  505
# downloading  339  of  505
# downloading  340  of  505
# downloading  341  of  505
# downloading  342  of  505
# downloading  343  of  505
# downloading  344  of  505
# downloading  345  of  505
# downloading  346  of  505
# downloading  347  of  505
# downloading  348  of  505
# downloading  349  of  505
# downloading  350  of  505
# downloading  351  of  505
# downloading  352  of  505
# downloading  353  of  505
# downloading  354  of  505
# downloading  355  of  505
# downloading  356  of  505
# downloading  357  of  505
# downloading  358  of  505
# downloading  359  of  505
# downloading  360  of  505
# downloading  361  of  505
# downloading  362  of  505
# downloading  363  of  505
# downloading  364  of  505
# downloading  365  of  505
# downloading  366  of  505
# downloading  367  of  505
# downloading  368  of  505
# downloading  369  of  505
# downloading  370  of  505
# downloading  371  of  505
# downloading  372  of  505
# downloading  373  of  505
# downloading  374  of  505
# downloading  375  of  505
# downloading  376  of  505
# downloading  377  of  505
# downloading  378  of  505
# downloading  379  of  505
# downloading  380  of  505
# downloading  381  of  505
# downloading  382  of  505
# downloading  383  of  505
# downloading  384  of  505
# downloading  385  of  505
# downloading  386  of  505
# downloading  387  of  505
# downloading  388  of  505
# downloading  389  of  505
# downloading  390  of  505
# downloading  391  of  505
# downloading  392  of  505
# downloading  393  of  505
# downloading  394  of  505
# downloading  395  of  505
# downloading  396  of  505
# downloading  397  of  505
# downloading  398  of  505
# downloading  399  of  505
# downloading  400  of  505
# downloading  401  of  505
# downloading  402  of  505
# downloading  403  of  505
# downloading  404  of  505
# downloading  405  of  505
# downloading  406  of  505
# downloading  407  of  505
# downloading  408  of  505
# downloading  409  of  505
# downloading  410  of  505
# downloading  411  of  505
# downloading  412  of  505
# downloading  413  of  505
# downloading  414  of  505
# downloading  415  of  505
# downloading  416  of  505
# downloading  417  of  505
# downloading  418  of  505
# downloading  419  of  505
# downloading  420  of  505
# downloading  421  of  505
# downloading  422  of  505
# downloading  423  of  505
# downloading  424  of  505
# downloading  425  of  505
# downloading  426  of  505
# downloading  427  of  505
# downloading  428  of  505
# downloading  429  of  505
# downloading  430  of  505
# downloading  431  of  505
# downloading  432  of  505
# downloading  433  of  505
# downloading  434  of  505
# downloading  435  of  505
# downloading  436  of  505
# downloading  437  of  505
# downloading  438  of  505
# downloading  439  of  505
# downloading  440  of  505
# downloading  441  of  505
# downloading  442  of  505
# downloading  443  of  505
# downloading  444  of  505
# downloading  445  of  505
# downloading  446  of  505
# downloading  447  of  505
# downloading  448  of  505
# downloading  449  of  505
# downloading  450  of  505
# downloading  451  of  505
# downloading  452  of  505
# downloading  453  of  505
# downloading  454  of  505
# downloading  455  of  505
# downloading  456  of  505
# downloading  457  of  505
# downloading  458  of  505
# downloading  459  of  505
# downloading  460  of  505
# downloading  461  of  505
# downloading  462  of  505
# downloading  463  of  505
# downloading  464  of  505
# downloading  465  of  505
# downloading  466  of  505
# downloading  467  of  505
# downloading  468  of  505
# downloading  469  of  505
# downloading  470  of  505
# downloading  471  of  505
# downloading  472  of  505
# downloading  473  of  505
# downloading  474  of  505
# downloading  475  of  505
# downloading  476  of  505
# downloading  477  of  505
# downloading  478  of  505
# downloading  479  of  505
# downloading  480  of  505
# downloading  481  of  505
# downloading  482  of  505
# downloading  483  of  505
# downloading  484  of  505
# downloading  485  of  505
# downloading  486  of  505
# downloading  487  of  505
# downloading  488  of  505
# downloading  489  of  505
# downloading  490  of  505
# downloading  491  of  505
# downloading  492  of  505
# downloading  493  of  505
# downloading  494  of  505
# downloading  495  of  505
# downloading  496  of  505
# downloading  497  of  505
# downloading  498  of  505
# downloading  499  of  505
# downloading  500  of  505
# downloading  501  of  505
# downloading  502  of  505
# downloading  503  of  505
# downloading  504  of  505

# %%
dfAnalysts = pd.concat(dfAnalysts)

# %%
dfAnalysts
# Out:
#      Buy  Overweight  Hold  Underweight  Sell Symbol Analyst_Price Analyst_Rec
# 0      3           0    13            0     3    MMM        168.44        Hold
# 1      5           0     7            0     1    AOS         48.63  Overweight
# 2     14           2     3            1     1    ABT        106.38  Overweight
# 3     11           1     4            0     0   ABBV        110.14  Overweight
# 4      4           0     4            0     1   ABMD        253.40  Overweight
# ..   ...         ...   ...          ...   ...    ...           ...         ...
# 499    6           3    17            0     1    YUM         98.52        Hold
# 500    3           2     5            0     0   ZBRA        286.71  Overweight
# 501   18           2     7            0     1    ZBH        146.04  Overweight
# 502    6           1    17            0     1   ZION         36.48        Hold
# 503   12           0     6            0     1    ZTS        146.50  Overweight
#
# [504 rows x 8 columns]

# %%
import yfinance as yf
def Pricing(ticker, dstart, dend, Type):

    df = yf.download(ticker, 
                          start=dstart, 
                          end = dend,
                          progress=False, group_by = 'Symbol')

    df = df.reset_index()
    df = df.melt(id_vars = 'Date', var_name = ['Symbol', 'Type'])
    df = df[df.Type == Type]
    
    return df

# %%
def RollingPrice(sdate, edate, lookback, Stocks):
    YTDPrice = Pricing(Stocks, sdate, edate, 'Close')
    YTDPrice = YTDPrice.sort_values(by = ['Symbol','Date'])
    
    YTDPrice['SMA'] = YTDPrice.value.rolling(window = lookback).mean()
    YTDPrice['STD'] = YTDPrice.value.rolling(window = lookback).std()
    YTDPrice['UpperB'] = (YTDPrice.STD * 2) + YTDPrice.value
    YTDPrice['LowerB'] = (YTDPrice.STD * -2) + YTDPrice.value
    
    
    Max = YTDPrice[YTDPrice.Date == YTDPrice.Date.max()]
    
    df = Max.loc[:,('Symbol', 'value', 'SMA', 'STD', 'UpperB', 'LowerB')]
    
    
    return df

# %%
df = RollingPrice('2020-01-01', '2020-07-18', 20, list(Company.Symbol))
# Out:
# 2 Failed downloads:
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted

# %%
df
# Out:
#        Symbol       value         SMA        STD      UpperB      LowerB
# 92611       A   94.370003   89.308500   2.108188   98.586378   90.153627
# 332635    AAL   11.910000   12.801500   1.169725   14.249449    9.570551
# 218377    AAP  144.860001  141.462500   4.809549  154.479099  135.240902
# 143575   AAPL  385.309998  371.774498  12.468132  410.246261  360.373735
# 89323    ABBV  100.830002   98.128000   1.522770  103.875542   97.784461
# ...       ...         ...         ...        ...         ...         ...
# 364693    YUM   90.570000   87.500500   1.458256   93.486512   87.653488
# 225775    ZBH  135.139999  121.773000   5.645180  146.430360  123.849639
# 297289   ZBRA  273.100006  258.923501   6.894559  286.889125  259.310888
# 163303   ZION   32.560001   33.111000   1.436904   35.433810   29.686193
# 158371    ZTS  144.660004  137.922500   3.159737  150.979477  138.340530
#
# [505 rows x 6 columns]

# %%
dfFinal = pd.merge(df, dfAnalysts, on = 'Symbol')
dfFinal = pd.merge(dfFinal, Company, on = 'Symbol')

# %%
os.chdir(exportpath)

dfFinal.Analyst_Price = dfFinal.Analyst_Price.astype('float')
dfFinal['Total_Ratings'] = dfFinal.Buy + dfFinal.Overweight + dfFinal.Hold + dfFinal.Underweight + dfFinal.Sell
dfFinal['Percent_Buy'] = dfFinal.Buy / dfFinal.Total_Ratings
dfFinal.to_csv(exportfile)
